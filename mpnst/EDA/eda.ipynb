# %%
import pandas as pd

df = pd.read_csv('/people/moon515/mpnst_smile_model/2024_05_17/broad_sanger_experiments.tsv', sep='\t')

# %%
df
# Out:
#               source  improve_sample_id improve_drug_id   study  time  \
# 0         pharmacoGX                1.0       SMI_12508    gCSI    72
# 1         pharmacoGX                1.0       SMI_13125    gCSI    72
# 2         pharmacoGX                1.0       SMI_13682    gCSI    72
# 3         pharmacoGX                1.0       SMI_16078    gCSI    72
# 4         pharmacoGX                1.0       SMI_25225    gCSI    72
# ...              ...                ...             ...     ...   ...
# 43651125  pharmacoGX             1924.0        SMI_5902  GDSCv2    72
# 43651126  pharmacoGX             1924.0        SMI_6479  GDSCv2    72
# 43651127  pharmacoGX             1924.0        SMI_6732  GDSCv2    72
# 43651128  pharmacoGX             1924.0        SMI_8498  GDSCv2    72
# 43651129  pharmacoGX             1924.0        SMI_8793  GDSCv2    72
#
#          time_unit dose_response_metric  dose_response_value
# 0            hours              fit_auc               2.6670
# ...

# %%
import pandas as pd

# Load the data
df = pd.read_csv('/people/moon515/mpnst_smile_model/2024_05_17/broad_sanger_experiments.tsv', sep='\t')

# Group by 'study' and 'dose_response_metric' and count occurrences
availability = df.groupby(['study', 'dose_response_metric']).size().reset_index(name='count')

# Display the availability
print(availability)
# Out:
#    study dose_response_metric  count
# 0   CCLE                  aac  11566
# 1   CCLE                  auc  11566
# 2   CCLE                  dss  11566
# 3   CCLE              fit_auc  11566
# 4   CCLE             fit_ec50  11566
# ..   ...                  ...    ...
# 75  gCSI           fit_ec50se  13258
# 76  gCSI             fit_einf  13258
# 77  gCSI               fit_hs  13258
# 78  gCSI             fit_ic50  13258
# 79  gCSI               fit_r2  13258
#
# [80 rows x 3 columns]

# %%
availability
# Out:
#    study dose_response_metric  count
# 0   CCLE                  aac  11566
# 1   CCLE                  auc  11566
# 2   CCLE                  dss  11566
# 3   CCLE              fit_auc  11566
# 4   CCLE             fit_ec50  11566
# ..   ...                  ...    ...
# 75  gCSI           fit_ec50se  13258
# 76  gCSI             fit_einf  13258
# 77  gCSI               fit_hs  13258
# 78  gCSI             fit_ic50  13258
# 79  gCSI               fit_r2  13258
#
# [80 rows x 3 columns]
